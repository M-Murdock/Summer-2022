# %% [markdown]
# Converts xml file containing Crosby and Shaeffer vocabulary to a csv file containing only the vocabulary lists

# %%
import re
import wget
import pandas as pd

# %% [markdown]
# ### Get the xml file

# %%
# !pip install wget
# !wget crosbyshaeffer2.0.xml https://github.com/gregorycrane/CrosbyShaeffer2.0/blob/51a1e5d7663f6944816d11853f1aa21004838323/crosbyshaeffer2.0.xml
# Out:
# Requirement already satisfied: wget in /opt/anaconda3/lib/python3.8/site-packages (3.2)

# %%
file_path = './lib/crosbyshaeffer_vocabulary_unprocessed.xml'
url = 'https://github.com/gregorycrane/CrosbyShaeffer2.0/blob/51a1e5d7663f6944816d11853f1aa21004838323/crosbyshaeffer2.0.xml'
wget.download(url, file_path)
# Out:
# './lib/crosbyshaeffer2.0 (1).xml'

# %% [markdown]
# Use regex to capture the info between `<p>VOCABULARY` and `</p>`

# %%
capture = False
vocab = []

# get rid of irrelevant lines
with open(file_path) as f:
    for line in f:
        if re.search(r"VOCABULARY", line):
            capture = True
        if re.search(r"\</p>", line):
            capture = False
        # capture everything within the <p></p>
        if capture:
            # otherwise, grab only the relevant info from within the tags
            match = re.search(r">((\w)+.*)<\/", line)
            if match is not None:
                cleaned_match = re.sub(r"<.*>", '', match.group(1))
                cleaned_match = re.sub(r"[&/;]", '', cleaned_match)
                vocab.append(cleaned_match)

# %%
# continue to clean the file

# remove any lines starting with numbers
# remove any lines not starting with greek letters
# remove any lines without a colon
remove = []
for line in vocab:
    if re.search(r"^[0-9]", line) or (not re.search('^[\u0370-\u03FF]', line)) or (not re.search(':', line)):
        remove.append(line)
        
for i in remove:
    vocab.remove(i)

for v in vocab:
    print(v)
# Out:
# παύουσι: they stop.
# πέμπει: he, she, or it sends (transitive).
# πέμπουσι: they send.
# ποταμός, -οὔ, ὃ: river, HIPPOPOTAMUS.
# στρατηγός, -οὔ, ὃ: general. STRATEGY.
# δίκαιος : just.
# μακρός: large. MACRON. MACROECONOMICS.
# μῑκρός: small. MICROSCOPIC. MICROECONOMICS
# πόλεμος: war.
# πολέμιος : hostile.
# οἱ πολέμιοι: the enemy. POLEMIC.
# φίλος: friend. PHILANTHROPIST.
# γράφω: write. TELEGRAPH. LITHOGRAPH.
# καί: conj.: and, also, even.
# καλός: beautiful, honorable, fine.
# κίνδυνος: danger.
# λίθος: stone.
# λύω: loose, break, destroy.
# παύω: stop (trans,). PAUSE.ltgt
# δέ (δ᾽ before vowels), postpos.2 conj: but, and.
# δένδρον: tree. RHODODENDRON.
# παρά, prep.: with G., from the side of with D., by the side of with A., to the side of, to, alongside. PARALLEL.
# δῆλος: plain, evident.
# δῶρον: gift. THEODORE,
# εἰς, proclit. prep. with A.: into  (Lat. in).
# πεδίον: plain.
# στάδιον: stadium (race course) stade (600 ft.).3 ltgt
# γάρ, postpos. conj. : for.
# σπονδή: libation pl, treaty, truce. SPONDEE.
# κώμη: village.
# μάχῃ: battle. LOGOMACHY.
# φεύγω: flee. Lat. fugio. FUGITIVE,
# βλάπτω, βλάψω, ἔβλαψα, βλαφα, βέβλαμμαι, ἐβλάφθην, ἐβλάβην : harm, hinder.
# πλέθρον, -ου. τό : plethron (100 ft.)
# σημαίνω, σημανῶ, ἐσήμηνα, σεσήμασμαι, ἐσημάνθην: give a signal, signify, betoken. SEMANTIC, SEMAPHORE.
# βασιλεία: kingdom.1 Cf. βασίλειος
# κοινός: common.
# νόμος, νόμου, ὁ: usage, law. Cf.   νομίζω, DEUTERONOMY.
# οἵομαι, οἴησομαι, ᾠήθην: think, suppose.

# %% [markdown]
# Put everything into a dictionary

# %%
table = {"word": [], "translation":[], "cognate":[]}

for v in vocab:  
    
    # get the greek word
    word_match = re.search(r"(.+):", v)
    if word_match is not None:
        table["word"].append(word_match.group(0).strip(" :"))
    else:
        table["word"].append("N/A")
        
        
    # get the english translation
    transl_match = re.search(r":(.+)", v)
    if transl_match is not None:
        eng_trans_list = []
        # get the entire string
        w = transl_match.group(0).strip(" :")
        print(w)
        # get each of the words (separated by periods)
        for i in re.split("[.,]", w):
            i = i.strip(" ")
            # if the word is all uppercase, ignore it
            if not i.isupper():
                eng_trans_list.append(i)
        # recombine all the words we want, separated by periods
        table["translation"].append(".".join(eng_trans_list))
        
    else:
        table["translation"].append("N/A")
        
        
    # get the cognate
    cognate_match = re.search(r"[A-Z][A-Z]+", v) 
    if cognate_match is not None:
        table["cognate"].append(cognate_match.group(0))
    else:
        table["cognate"].append("N/A")
# Out:
# they stop.
# he, she, or it sends (transitive).
# they send.
# river, HIPPOPOTAMUS.
# general. STRATEGY.
# just.
# large. MACRON. MACROECONOMICS.
# small. MICROSCOPIC. MICROECONOMICS
# war.
# hostile.
# the enemy. POLEMIC.
# friend. PHILANTHROPIST.
# write. TELEGRAPH. LITHOGRAPH.
# conj.: and, also, even.
# beautiful, honorable, fine.
# danger.
# stone.
# loose, break, destroy.
# stop (trans,). PAUSE.ltgt
# but, and.
# tree. RHODODENDRON.
# with G., from the side of with D., by the side of with A., to the side of, to, alongside. PARALLEL.
# plain, evident.
# gift. THEODORE,
# into  (Lat. in).
# plain.
# stadium (race course) stade (600 ft.).3 ltgt
# for.
# libation pl, treaty, truce. SPONDEE.
# village.
# battle. LOGOMACHY.
# flee. Lat. fugio. FUGITIVE,
# not, UTOPIA. PROPHYLACTIC.
# flight, exile. Lat fuga.
# guard, garrison.
# tent. SCENE.
# guard (verb).ltgt
# ten. DECALOGUE.
# with G., through  with A., on account of. DIAMETER.
# friendship. Cf. φίλος.
# friendly.
# foreigner, barbarian.
# outcry, shout.
# word, speech.
# coord. conj. (§ 45).
# silence.ltgt
# intend, delay, be about to, usually with fut. inf.
# pursue.
# door αἱ θύραι: often used of military head-quarters or of the king#39s court (compare Sublime Porte). THYROID.
# 1 believe, think, with inf.
# persuade.
# left, remaining
# the future: κ.τ.λ. (καὶ τὰ λοιπά) : etc.
# house. ECONOMY.
# gate pl., pass. PYLON. THERMOPYLA.
# leave. ECLIPSE.ltgt
# a running, run, race, race course. HIPPODROME.
# hasten.ltgt
# same, self, he, she, it, they, etc. AUTOMATON.
# plan,
# plan, BOULE.
# order, command,
# ltgt cross.
# 2 crossable.
# ltgt advise, with D. of
# full, full of, the person. with G.
# this (as aforesaid).
# boat.
# grain, food.  PARASITE.
# with. SYNOD.
# queen.
# bridge.
# if. frequently pl, arms (in war). PANOPLY.
# sea.
# bad, cowardly. CACOPHONY.
# therefore, then,  accordingly.
# not, Found instead of οὐ with most uses of the infinitive and in conditional clauses.
# thou, you.ltgt
# 2 remain, wait for.
# Xenias, an Arcadian general serving under Cyrus, the younger.
# citizen, POLITICS,
# satrap, a Persian viceroy.
# Of yourself.
# haiting-place, day’s march,
# soldier. Cf. στρατιά, στρατηγός.
# be.
# not yet.
# be present.
# five. PENTAGON.
# camp. Cf. στρατιά and πεδίον.
# place. TOPOGRAPUY.
# then, at that time.
# he or she says, PROPHET.
# ὡς (45) πολεμίαν. ἐντεῦθεν Κῦρος τὴν Κίλισσαν
# woman, wife.  MISOGYNIST.
# plunder, pillage, sack.
# Thracian.
# trumpet.
# with G., down from with A., down along, along, according to. CATALOGUE.
# phalanx, battle-line.
# guard. Cf. φυλακή, φυλάττω.
# herald.
# with G., from the side of, in the sight of with D., near, beside, besides  with A., to the side of, toward. PROSELYTE.ltgt
# fact, business  pl. trouble. PRAGMATIC.
# spear. DORYPHOROS.
# fuvor, gratiiude. χάριν ἔχω: feel grateful, with D. EUCHARIST.
# thing pl., things, ie., property, wealth, money.
# night. Lat. nox.
# boy, girl, child. PEDAGOGUE.
# prevent. KOLYNOS.ltgt
# trust, with D.
# turn.
# take, receive.  SYLLABLE. (Future, page 187.)
# turn, “bent,” manner, character, TROPIC,
# exile, fugitive. Cf. φυγή.
# furnish, cause.
# then, next.
# thus, so, as afore- said. Cf. οὗτος.
# sing., every, whole  pl. all. PANDEMONIUM.
# first: πρῶτον, adv. at first. PROTOTYPE.
# fear. HYDROPHOBIA.
# ask for, demand.
# now, then, accordingly, indeed, etc. Often untranslated.
# seem, seem best, think, Often with inf. as subject. DOGMATIC.
# call, name. CALENDAR.
# make, do. POET (ποιητής).
# make war. Cf. πόλεμος.
# love. Cf. φίλος.
# send after, sum-
# wish, desire. mon.
# journey.
# journey, march,
# fight, give battle. Cf. μάχη.
# with G., with  with  A., after as a prefix, often denotes change. METAPHOR.
# take, seize, capture mid. take for yourself, choose. HERESY.
# master. DESPOT.
# right, righthand, clever : ἡ δεξιᾷ: the right. Lat. dexter.
# become, be born, be, prove to be, ecliptic. GENESIS.
# accept, await, receive.
# Be.
# spirit, temper, mind.
# new, young, fresh. Lat. novus, NEOPHYTE.
# prepare mid., prepare oneself or for oneself.
# eager, ready.
# hard, severe.ltgt
# second. DEUTERONOMY.
# table.  TRAPEZOID.
# third, TRISYLLABIC.
# well. Cf. καλός.
# head. CEPHALIC.
# not longer, no longer, never again, ltgt
# now. . Lat. nune.
# how large pl., how many?
# when?
# “somewhen,” once.
# where?
# somewhere.
# how ?
# somehow, in any way.
# who, what?
# some, any.
# time. CHRONOMETER
# neither nor.
# be treated, experience, suffer. SYMPATHY.
# no longer, never again.
# neither...nor.
# and. Usually followed by kai: both .. . and.
# bear, carry. CHRISTOPHER.
# be necessary. Usually followed by A. and inf.
# teach. DIDACTIC.
# rather (than), more (than).
# long ago. PALAEOZOIC.
# wise. SOPHOMORE.
# wisdom. SOPHIA.
# life, living.  BIOLOGY.
# indeed, at least,
# god (4 Oeds: goddess). THEOLOGY. Cf. θεά
# pay.
# stranger, guest or host, mercenary, i.e, hired soldier.
# toil, labor, travail.
# do, fare. PRACTICAL. Cf. πρᾶγμα.
# gold, money.
# gold, gold metal. CHRYSANTHEMUM.
# πάντα ἄρα (therefore) τῶν σοφῶν.
# bring, supply.
# make campaign. Usually mid.
# justice. Cf. στρατιά.
# order, arrange, station. TAXIDERMIST, TACTICS.
# wine.
# nourish, support, rear, keep (of animals). ATROPHY.
# again, back,  PALINODE. ltgt
# ἐκ τούτου πάλιν ὁ
# Ἔτι οὖν ἂν γένοιο τῷ ἐμῷ (my) ἀδελφῷ
# and not, nor, not even.
# save, bring safety, rescue.  SOZODONT, CREOSOTE.
# death. THANATOPSIS.
# and  not, nar, not even.
# safety.
# wonder, marvel at, admire. THAUMATURGY.
# perceive. ANESTHESIA.
# know, determine, DIAGNOSIS. cf. γνώμη.
# say, tell, speak, Cf. DIALECT.
# inquire, learn (by inquiry).
# find. EUREKA,
# pray,  vow.
# however.
# Xenophon.
# sacrifice. πότερος, pron.: which (of two) mérepoy, adv.: whether. Often fol. by ἤ or.
# captain. Cf. στρατηγός.
# company.
# month. Cf. Moon,
# fatherland.
# well. EULOGY.
# lucky, prosperous, EUDAMONISM.ltgt
# fullness, quantity. PLETHORIC.
# birth, family, kind. multitude, hence “ the masses.” Lat. genus. Cf. ἐγενόμην. GENEALOGY.
# Socrates.
# breadth.
# wall (of fortification).
# Themistocles.
# trireme, war vessel, with three (τρι-) banks of oars.
# part, share, role. ltgt
# straight, direct
# before, in front of. PROLOGUE.
# straightway, immediately.
# swift.
# end A. used as adv. : finally. TELEOLOGICAL.
# great, large. MEGALOMANIA.
# except.
# much pl.  many οἱ πολλοί: the majority.  POLYGON. ltgt
# shameful, ugly. Opposite of καλός.
# responsible, accountable  with G., responsible for.
# to be feared, terrible, skilful, clever. Cf. DINOSAURUS
# faithful, trusty.
# fearful, frightful. Cf. φόβος.
# wholly, very. Ch. mas.
# from the front, in front, before. Cf. ὄπισθεν.
# overpower, conquer. Cf. κράτιστος, DEMOCRATIC.
# power. aside.
# mouth, van (of an army).ltgt
# run.
# ship. NAUSEA.
# king. Cf. βασίλεια, Basilea. BASIL.
# fall.
# be king aor. became king.
# city, state, Cf. πολίτης. POLITICAL.
# with D., run to aid (at a shout for help), assist.
# narrow. STENOGRAPHIC.
# old man.
# horn, wing (milit.). Lat. cornu. RHINOCEROS
# father. Lat. pater.
# (sing. only): fire. PYROTECHNIC,
# thy, thine, (sing.). Cf. σύ.
# body. CHROMOSOME.
# Μὰ Δί (No, by
# τί οὖν οὗτοι
# 2 go. ANABASIS
# 3 throw, pelt εἰσβάλλω(milit.): invade. PROBLEM, BALLISTICS.
# place, spot. Dimin. of χώρα.ltgt
# Zeus.
# have courage.
# memorial, monument.
# stretch, reach. Lat. teneo.
# be necessary, fitting.
# middle τὸ μέσον: the middle. MESOPOTAMIA.
# again, on the other hand.
# army. Cf. στρατεύω.
# turn. (rel.). STREPTOCOCCUS, STROPHE.ltgt
# νομιῶ, νομιεῖς, νομιεῖ, κ.τ.λ.
# καλῶ, καλεῖς, καλεῖ, κ.τ.λ.
# μαχοῦμαι, μαχεῖ, μαχεῖται, κ.τ.λ.
# look to see, inquire, consider. MICROSCOPE, PERISCOPE.
# shed light, show mid. and pass., appear. PHENOMENON,
# land, soil. GEOLOGY.
# pick out, judge, decide, CRISIS, CRITIC.
# visible, apparent, evident. PHANEROGAM.
# look to see, inquire, consider. SCEPTIC.ltgt
# O if, would that, if only.
# , cut, ANATOMY.
# peace. IRENIC
# fitting moment, opportunity.
# run, TROCHAIC, Cf. δρόμος.
# learn, understand. POLYMATH.
# 1 fear. Cf. φόβος.
# is a care, concerns. Used impersonally.
# be severe, angry. Ci. χαλεπός.ltgt
# fear. πέπονθα (πάσχω) : have left.
# have taken. πέπεικα (πείθω): have persuaded.
# have sent.
# have found.
# hare experienced, have been treated.
# be dead.
# dig, bury. EPITAPH. Cf. @θάπτω.
# parasang. A Persian road measure = about 30 stades.
# burial, grave.
# remind μέμνημαι: remember, MNEMONIC.
# ditch, trench. Cf. θάπτω.
# dwell, inhabit. ECUMENICAL. Cf. οἰκία.
# honor, price. TIMOCRACY.ltgt
# Κῦρος δὲ οὔπω
# rub through or away, spend, waste (time), delay. DIATRIBE.
# lack, need, want, desire, request. Freq with G., or with G. of pers. and inf. Cf. δεῖ
# javelin.
# nature. PHYSICS.ltgt
# no one, no.
# no one, no.ltgt
# sell.
# be able, DYNAMIC.
# powerful, able, capable.
# gain, profit, pay.
# send. APOSTOLIC, PERISTALTIC.
# then, therefore.
# ox, cow.
# therefore.
# strike. ANAPAEST.
# mind ἐν νῷ ἔχω:intend τὸν νοῦν προσ-έχω: attend, i.e. pay heed.
# say.
# false. PSEUDONYM, PSEUDOSCIENTIFIC.
# deceive middle, lie.ltgt
# wood. XYLOPHONE.
# put, place.  Frequently in compounds. ANTITHESIS.
# saw.
# of such sort,  such size or quantity.
# haste, zeal. Cf. σπεύδω.
# lie, he placed. Freq. instead of τέθειμαι.
# crown, wreath, STEPHEN.
# distribute, assign.
# hit, attain, with G. happen, with suppl. part.
# earnest, zealous, serious, weighty. ltgt
# give. Cf. δῶρον. DOSE.
# well-intentioned, well-disposed. Cf. εὖ and νοῦς.
# although.
# not never, never,
# not ever, never.
# twice. Cf. δύο. DISSYLLABIC.
# sailing, voyage. Cf. πλέω, πλοῖον.ltgt
# until, while. Also  used as a prep. with G.: up to.
# end, finish, die.
# contrive.
# honor, reward,
# contrivance, device, machine. Cf, Lat. machina.  pay. Cf. MECHANICAL.ltgt
# force, violence. Cf. δύναμις: force, power.
# conquer,  win.
# spend, waste.
# victory. EUNICE.
# know.
# blame, accuse, find fault.  Cf. αἴτιος.
# go.
# seer, soothsayer, prophet, MANTIC, NECROMANCY.
# try. PIRATE, EMPIRIC.
# order, arrangement, position, division. Cf, τάττω. TAXIDERMIST.
# use. with D. Cf. χρῆμα.ltgt
# be a slave (δοῦλος), serve.
# drink, Cf. Lat. bibο.
# mortal, human.  Cf.  ἀπο-θνῄσκω.
# art, skill, craft. TECHNIQUE.
# haven, harbor.
# chance, lot, fate. Cf. τυ(γ)χάνωltgt
# εὐ-μενὴς (kindly-minded) γὰρ ἡ θεός,
# show, point out, PARADIGM.
# i yoke, bind, unite.
# corpse. NECROSIS.
# look, face, point.
# live τὸ ζῶον: living thing. ZOOLOGY.
# bare, naked, lightly-clad, GYMNAST.
# toil, struggle. Cf. πόνος.
# distinguish, decide  between. DIAGNOSIS.
# leisure, free time for anything, SCHOLAR.ltgt
# make plain, show. Cf. δῆλος.
# gain, get possession of.
# wound. TRAUMA.
# breastplate, corselet, cuirass. THORAX, THORACIC.
# escape notice, elude do secretly, with suppl. part. Usually with suppl. part.1 LETHE.
# infantryman
# outstrip, beat, anticipate.
# ὥστε ἐπιέζετο (was burdened).
# royal τὰ βασίλεια: palace. BASILICA.
# circle, CYCLE.
# peltast, a light-armed soldier.
# spear point, spear,
# hill, crest, plume.
# noise, din, outcry.
# burn, CAUSTIC.
# siege. Cf. πόλις.
# avenge  mid., punish. With D. of person avenged, A. of person punished.
# harm, hinder.
# plethron (100 ft.)
# give a signal, signify, betoken. SEMANTIC, SEMAPHORE.
# kingdom.1 Cf. βασίλειος
# common.
# usage, law. Cf.   νομίζω, DEUTERONOMY.
# think, suppose.

# %% [markdown]
# Convert the dictionary to a dataframe

# %%
df = pd.DataFrame(data=table)
print(df)
# Out:
#                                                 word  \
# 0                                            παύουσι
# 1                                             πέμπει
# 2                                           πέμπουσι
# 3                                    ποταμός, -οὔ, ὃ
# 4                                  στρατηγός, -οὔ, ὃ
# ..                                               ...
# 396  σημαίνω, σημανῶ, ἐσήμηνα, σεσήμασμαι, ἐσημάνθην
# 397                                         βασιλεία
# 398                                           κοινός
# 399                                  νόμος, νόμου, ὁ
# 400                          οἵομαι, οἴησομαι, ᾠήθην
#
#                           translation       cognate
# 0                          they stop.           N/A
# 1    he.she.or it sends (transitive).           N/A
# 2                          they send.           N/A
# 3                              river.  HIPPOPOTAMUS
# 4                            general.      STRATEGY
# ..                                ...           ...
# 396    give a signal.signify.betoken.      SEMANTIC
# 397            kingdom.1 Cf.βασίλειος           N/A
# 398                           common.           N/A
# 399              usage.law.Cf.νομίζω.   DEUTERONOMY
# 400                    think.suppose.           N/A
#
# [401 rows x 3 columns]

# %% [markdown]
# Convert the dataframe to a csv

# %%
df.to_csv('./lib/crosbyshaeffer_vocabulary.csv', sep='\t', index=False)
