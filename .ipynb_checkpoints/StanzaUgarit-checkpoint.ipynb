# %% [markdown]
# Takes as input a comma-separated file with the format: `line number, question part, question, answer`. Each line represents a separate sentence. The first line must be: `line, part, greek, english`

# %% [markdown]
#     Step 0: Imports

# %%
import stanza
import pandas as pd

from xml.dom import minidom
import os 

import xml.etree.ElementTree as gfg 

import lxml

# !pip install pyconll
import pyconll

import glob
import csv


stanza.download('en')
stanza.download('grc')

nlp_grk = stanza.Pipeline('grc') 
nlp_en = stanza.Pipeline('en')
# Out:
# Requirement already satisfied: pyconll in /opt/anaconda3/lib/python3.8/site-packages (3.1.0)
# HBox(children=(HTML(value='Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/res…
# 2022-07-18 14:37:30 INFO: Downloading default packages for language: en (English)...
# 2022-07-18 14:37:31 INFO: File exists: /Users/mallard/stanza_resources/en/default.zip
# 2022-07-18 14:37:41 INFO: Finished downloading models and saved to /Users/mallard/stanza_resources.
# HBox(children=(HTML(value='Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/res…
# 2022-07-18 14:37:41 INFO: Downloading default packages for language: grc (Ancient_Greek)...
# 2022-07-18 14:37:41 INFO: File exists: /Users/mallard/stanza_resources/grc/default.zip
# 2022-07-18 14:37:43 INFO: Finished downloading models and saved to /Users/mallard/stanza_resources.
# HBox(children=(HTML(value='Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/res…
# 2022-07-18 14:37:43 INFO: Loading these models for language: grc (Ancient_Greek):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | proiel  |
# | pos       | proiel  |
# | lemma     | proiel  |
# | depparse  | proiel  |
# =======================
#
# 2022-07-18 14:37:43 INFO: Use device: cpu
# 2022-07-18 14:37:43 INFO: Loading: tokenize
# 2022-07-18 14:37:43 INFO: Loading: pos
# 2022-07-18 14:37:43 INFO: Loading: lemma
# 2022-07-18 14:37:43 INFO: Loading: depparse
# 2022-07-18 14:37:43 INFO: Done loading processors!
# HBox(children=(HTML(value='Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/res…
# 2022-07-18 14:37:45 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-07-18 14:37:45 INFO: Use device: cpu
# 2022-07-18 14:37:45 INFO: Loading: tokenize
# 2022-07-18 14:37:45 INFO: Loading: pos
# 2022-07-18 14:37:45 INFO: Loading: lemma
# 2022-07-18 14:37:45 INFO: Loading: depparse
# 2022-07-18 14:37:46 INFO: Loading: sentiment
# 2022-07-18 14:37:46 INFO: Loading: constituency
# 2022-07-18 14:37:47 INFO: Loading: ner
# 2022-07-18 14:37:47 INFO: Done loading processors!

# %% [markdown]
#     Step 1: Store contents of csv in dataframe

# %%
# def isValid(myList):
#     if myList[0][2] == '':
#         print("empty space found!")
#         return False
#     return True

# %%
# define the file names here:
file_list = glob.glob('lib/Crosby-Shaeffer-Lessons/*.csv')

file_lines = []

# loop through each file (lesson)
for x in file_list:
    # read the contents, save them as list
    with open(file_list[0], newline='') as f:
        reader = csv.reader(f, delimiter = ',')
        l = list(reader)
        if not l[0][0] == '':
            file_lines = file_lines + l
    
# convert the list to a dataframe
lines_df = pd.DataFrame(file_lines, columns=['line', 'part', 'greek', 'english'])

print(lines_df)
# Out:
#    line part                                              greek  \
# 0    34    a                                            σπονδῶν
# 1    34    a                                               φυγῇ
# 2    34    a                                              μάχην
# 3    34    a                                             κώμαις
# 4    34    a                                             σκηνάς
# ..  ...  ...                                                ...
# 58   34    b                            αἱ δὲ σκηναὶ δῆλαι ἦσαν
# 59
# 60   34    c                             τ-- δὲ κωμ-- ἦν φυλακή
# 61   34    c             οὐκ ἦσαν σκην-- τ-- φυλακ-- (singular)
# 62   34    c  -- (article) ἐν τῷ περδίῳ -- (negative adverb)...
#
#                  english
# 0    possession (plural)
# 1        indirect object
# 2          direct object
# 3        indirect object
# 4         direct objects
# ..                   ...
# 58  The tents were clear
# 59
# 60              τῇ, κώμῃ
# 61     σκηναὶ, τῇ φυλακῇ
# 62        οἷ, οὐκ, λύειν
#
# [63 rows x 4 columns]

# %% [markdown]
#     Step 2: Put dataframe info into lists

# %%
line_nums = lines_df['line'].tolist()
q_part = lines_df['part'].tolist()

greek_lines = lines_df['greek'].tolist()
english_lines = lines_df['english'].tolist()

# %% [markdown]
#     Step 3: Place the data on each word into a UD file format. Note that we can test this file with the CoNNL-U viewer.

# %% [markdown]
# Resources:
#
# [UD file format](https://universaldependencies.org/format.html)
#
# [CoNNL file viewer](https://universaldependencies.org/conllu_viewer.html)

# %%
treebank_file = 'UDtreebank.txt'
with open(treebank_file, 'w') as f:
      
    # loop through each line of text
    for index in range(0, len(english_lines)): 

        # get the data for each word
        grk_doc = nlp_grk(greek_lines[index])

        if len(grk_doc.sentences) > 0:
            for grk_token in grk_doc.sentences[0].words:
                # D: Word index, integer starting at 1 for each new sentence; may be a range for multiword tokens; may be a decimal number for empty nodes (decimal numbers can be lower than 1 but must be greater than 0).
                f.write(str(grk_token.id))
                f.write('\t')

                # FORM: Word form or punctuation symbol.
                f.write(grk_token.text)
                f.write('\t')

                # LEMMA: Lemma or stem of word form.
                f.write(grk_token.lemma)
                f.write('\t')

                # UPOS: Universal part-of-speech tag.
                f.write(grk_token.upos)
                f.write('\t')

                # XPOS: Language-specific part-of-speech tag; underscore if not available.
                f.write(grk_token.xpos)
                f.write('\t')

                # FEATS: List of morphological features from the universal feature inventory or from a defined language-specific extension; underscore if not available.
                f.write(str(grk_token.feats))
                f.write('\t')

                # HEAD: Head of the current word, which is either a value of ID or zero (0).
                f.write(str(grk_token.head))
                f.write('\t')

                # DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one.
                f.write(str(grk_token.deprel))
                f.write('\t')

                # DEPS: Enhanced dependency graph in the form of a list of head-deprel pairs.
                f.write(str(grk_token.deps))
                f.write('\t')

                # MISC: Any other annotation.
                # Sentence number/part
                f.write(str(line_nums[index]) + q_part[index])

                f.write('\n')

            f.write('\n')
        
        
        # get the data for each word
        en_doc = nlp_en(english_lines[index])

        if len(en_doc.sentences) > 0:
            for en_token in en_doc.sentences[0].words:
                # D: Word index, integer starting at 1 for each new sentence; may be a range for multiword tokens; may be a decimal number for empty nodes (decimal numbers can be lower than 1 but must be greater than 0).
                f.write(str(en_token.id))
                f.write('\t')

                # FORM: Word form or punctuation symbol.
                f.write(en_token.text)
                f.write('\t')

                # LEMMA: Lemma or stem of word form.
                f.write(en_token.lemma)
                f.write('\t')

                # UPOS: Universal part-of-speech tag.
                f.write(en_token.upos)
                f.write('\t')

                # XPOS: Language-specific part-of-speech tag; underscore if not available.
                f.write(en_token.xpos)
                f.write('\t')

                # FEATS: List of morphological features from the universal feature inventory or from a defined language-specific extension; underscore if not available.
                f.write(str(en_token.feats))
                f.write('\t')

                # HEAD: Head of the current word, which is either a value of ID or zero (0).
                f.write(str(en_token.head))
                f.write('\t')

                # DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one.
                f.write(str(en_token.deprel))
                f.write('\t')

                # DEPS: Enhanced dependency graph in the form of a list of head-deprel pairs.
                f.write(str(en_token.deps))
                f.write('\t')

                # MISC: Any other annotation.
                # Sentence number/part
                f.write(str(line_nums[index]) + q_part[index])

                f.write('\n')

            f.write('\n')


# Stanza Features (https://stanfordnlp.github.io/stanza/data_objects.html):

# "id"
# "text"
# "lemma"
# "upos"
# "xpos"
# "feats"
# "head"
# "deprel"
# "start_char"
# "end_char"
# "ner"


# UD Required Features:

# D: Word index, integer starting at 1 for each new sentence; may be a range for multiword tokens; may be a decimal number for empty nodes (decimal numbers can be lower than 1 but must be greater than 0).
# FORM: Word form or punctuation symbol.
# LEMMA: Lemma or stem of word form.
# UPOS: Universal part-of-speech tag.
# XPOS: Language-specific part-of-speech tag; underscore if not available.
# FEATS: List of morphological features from the universal feature inventory or from a defined language-specific extension; underscore if not available.
# HEAD: Head of the current word, which is either a value of ID or zero (0).
# DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one.
# DEPS: Enhanced dependency graph in the form of a list of head-deprel pairs.
# MISC: Any other annotation.
# Out:
# [[
#   {
#     "id": 1,
#     "text": "σπονδῶν",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυγῇ",
#     "lemma": "φυγή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 4
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "μάχην",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "κώμαις",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνάς",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυλακῆς",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σπονδαί",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# []
# [[
#   {
#     "id": 1,
#     "text": "οὐ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "φεύγομεν",
#     "lemma": "φεύγω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 3,
#     "end_char": 11
#   },
#   {
#     "id": 3,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 12,
#     "end_char": 14
#   },
#   {
#     "id": 4,
#     "text": "ταῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 15,
#     "end_char": 19
#   },
#   {
#     "id": 5,
#     "text": "μάχαις",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 20,
#     "end_char": 26
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "γὰρ",
#     "lemma": "γάρ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "iobj",
#     "start_char": 7,
#     "end_char": 13
#   },
#   {
#     "id": 4,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 14,
#     "end_char": 16
#   },
#   {
#     "id": 5,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 17,
#     "end_char": 22
#   },
#   {
#     "id": 6,
#     "text": "καλή",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 23,
#     "end_char": 27
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οἱ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 2,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δ",
#     "lemma": "δ",
#     "upos": "NUM",
#     "xpos": "Ma",
#     "head": 6,
#     "deprel": "nsubj",
#     "start_char": 3,
#     "end_char": 4
#   },
#   {
#     "id": 3,
#     "text": "'ἐν",
#     "lemma": "'ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 4,
#     "end_char": 7
#   },
#   {
#     "id": 4,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 8,
#     "end_char": 10
#   },
#   {
#     "id": 5,
#     "text": "κώμῃ",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 6,
#     "deprel": "obl",
#     "start_char": 11,
#     "end_char": 15
#   },
#   {
#     "id": 6,
#     "text": "φυλάττουσι",
#     "lemma": "φυλάσσω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 26
#   },
#   {
#     "id": 7,
#     "text": "τοὺς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 8,
#     "deprel": "det",
#     "start_char": 27,
#     "end_char": 31
#   },
#   {
#     "id": 8,
#     "text": "ἵππους",
#     "lemma": "ἵππος",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Masc|Number=Plur",
#     "head": 6,
#     "deprel": "obj",
#     "start_char": 32,
#     "end_char": 38
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 4,
#     "end_char": 8
#   },
#   {
#     "id": 3,
#     "text": "σπονδαὶ",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 9,
#     "end_char": 16
#   },
#   {
#     "id": 4,
#     "text": "τοῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 17,
#     "end_char": 21
#   },
#   {
#     "id": 5,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 7,
#     "deprel": "case",
#     "start_char": 22,
#     "end_char": 24
#   },
#   {
#     "id": 6,
#     "text": "τῷ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 25,
#     "end_char": 27
#   },
#   {
#     "id": 7,
#     "text": "πεδίῳ",
#     "lemma": "πεδίον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Neut|Number=Sing",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 28,
#     "end_char": 33
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 6,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "πέμπεις",
#     "lemma": "πέμπω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "δῶρα",
#     "lemma": "δῶρον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Neut|Number=Plur",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 21,
#     "end_char": 25
#   },
#   {
#     "id": 6,
#     "text": "καλά",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Plur",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 26,
#     "end_char": 30
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "ἡ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 4,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 1
#   },
#   {
#     "id": 2,
#     "text": "τοῦ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Gen|Definite=Def|Gender=Masc|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 2,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "στρατηγοῦ",
#     "lemma": "στρατηγός",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nmod",
#     "start_char": 6,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "φυγὴ",
#     "lemma": "φυγή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 7,
#     "deprel": "nsubj",
#     "start_char": 16,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 7,
#     "deprel": "advmod",
#     "start_char": 21,
#     "end_char": 24
#   },
#   {
#     "id": 6,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 7,
#     "deprel": "cop",
#     "start_char": 25,
#     "end_char": 27
#   },
#   {
#     "id": 7,
#     "text": "καλή",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 28,
#     "end_char": 32
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "ἐκ",
#     "lemma": "ἐκ",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 3,
#     "deprel": "case",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "τῆς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Gen|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 3,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "κώμης",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 7,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "ἄγει",
#     "lemma": "ἄγω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 17
#   },
#   {
#     "id": 5,
#     "text": "τοὺς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 6,
#     "deprel": "det",
#     "start_char": 18,
#     "end_char": 22
#   },
#   {
#     "id": 6,
#     "text": "πολεμίους",
#     "lemma": "πολέμιος",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 23,
#     "end_char": 32
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "αἱ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "σκηναὶ",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 6,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "δῆλαι",
#     "lemma": "δῆλος",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 18
#   },
#   {
#     "id": 5,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 4,
#     "deprel": "cop",
#     "start_char": 19,
#     "end_char": 23
#   }
# ]]
# []
# [[
#   {
#     "id": 1,
#     "text": "τ--",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 5,
#     "deprel": "discourse",
#     "start_char": 4,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "κωμ--",
#     "lemma": "κωμή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 5,
#     "deprel": "nsubj",
#     "start_char": 7,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 5,
#     "deprel": "cop",
#     "start_char": 13,
#     "end_char": 15
#   },
#   {
#     "id": 5,
#     "text": "φυλακή",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 22
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 4,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 4,
#     "deprel": "cop",
#     "start_char": 4,
#     "end_char": 8
#   },
#   {
#     "id": 3,
#     "text": "σκην--",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 9,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "τ--",
#     "lemma": "τίς",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Masc|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 19
#   },
#   {
#     "id": 5,
#     "text": "φυλακ--",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nmod",
#     "start_char": 20,
#     "end_char": 27
#   },
#   {
#     "id": 6,
#     "text": "(singular)",
#     "lemma": "(singular)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "advmod",
#     "start_char": 28,
#     "end_char": 38
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "--",
#     "lemma": "--",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 9,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "(article)",
#     "lemma": "(article)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 9,
#     "deprel": "nsubj",
#     "start_char": 3,
#     "end_char": 12
#   },
#   {
#     "id": 3,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 13,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "τῷ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 16,
#     "end_char": 18
#   },
#   {
#     "id": 5,
#     "text": "περδίῳ",
#     "lemma": "περδίον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Neut|Number=Sing",
#     "head": 9,
#     "deprel": "obl",
#     "start_char": 19,
#     "end_char": 25
#   },
#   {
#     "id": 6,
#     "text": "--",
#     "lemma": "--",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 9,
#     "deprel": "advmod",
#     "start_char": 26,
#     "end_char": 28
#   },
#   {
#     "id": 7,
#     "text": "(negative",
#     "lemma": "(negative",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 8,
#     "deprel": "amod",
#     "start_char": 29,
#     "end_char": 38
#   },
#   {
#     "id": 8,
#     "text": "adverb)",
#     "lemma": "adverb)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 39,
#     "end_char": 46
#   },
#   {
#     "id": 9,
#     "text": "ἐθέλουσι",
#     "lemma": "ἐθέλω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Number=Plur|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 47,
#     "end_char": 55
#   },
#   {
#     "id": 10,
#     "text": "τὰς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 11,
#     "deprel": "det",
#     "start_char": 56,
#     "end_char": 59
#   },
#   {
#     "id": 11,
#     "text": "σπνδὰς",
#     "lemma": "σπνδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Plur",
#     "head": 9,
#     "deprel": "obj",
#     "start_char": 60,
#     "end_char": 66
#   },
#   {
#     "id": 12,
#     "text": "λυ--",
#     "lemma": "λυ--",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 11,
#     "deprel": "nmod",
#     "start_char": 67,
#     "end_char": 71
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σπονδῶν",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυγῇ",
#     "lemma": "φυγή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 4
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "μάχην",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "κώμαις",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνάς",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυλακῆς",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σπονδαί",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# []
# [[
#   {
#     "id": 1,
#     "text": "οὐ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "φεύγομεν",
#     "lemma": "φεύγω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 3,
#     "end_char": 11
#   },
#   {
#     "id": 3,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 12,
#     "end_char": 14
#   },
#   {
#     "id": 4,
#     "text": "ταῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 15,
#     "end_char": 19
#   },
#   {
#     "id": 5,
#     "text": "μάχαις",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 20,
#     "end_char": 26
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "γὰρ",
#     "lemma": "γάρ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "iobj",
#     "start_char": 7,
#     "end_char": 13
#   },
#   {
#     "id": 4,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 14,
#     "end_char": 16
#   },
#   {
#     "id": 5,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 17,
#     "end_char": 22
#   },
#   {
#     "id": 6,
#     "text": "καλή",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 23,
#     "end_char": 27
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οἱ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 2,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δ",
#     "lemma": "δ",
#     "upos": "NUM",
#     "xpos": "Ma",
#     "head": 6,
#     "deprel": "nsubj",
#     "start_char": 3,
#     "end_char": 4
#   },
#   {
#     "id": 3,
#     "text": "'ἐν",
#     "lemma": "'ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 4,
#     "end_char": 7
#   },
#   {
#     "id": 4,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 8,
#     "end_char": 10
#   },
#   {
#     "id": 5,
#     "text": "κώμῃ",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 6,
#     "deprel": "obl",
#     "start_char": 11,
#     "end_char": 15
#   },
#   {
#     "id": 6,
#     "text": "φυλάττουσι",
#     "lemma": "φυλάσσω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 26
#   },
#   {
#     "id": 7,
#     "text": "τοὺς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 8,
#     "deprel": "det",
#     "start_char": 27,
#     "end_char": 31
#   },
#   {
#     "id": 8,
#     "text": "ἵππους",
#     "lemma": "ἵππος",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Masc|Number=Plur",
#     "head": 6,
#     "deprel": "obj",
#     "start_char": 32,
#     "end_char": 38
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 4,
#     "end_char": 8
#   },
#   {
#     "id": 3,
#     "text": "σπονδαὶ",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 9,
#     "end_char": 16
#   },
#   {
#     "id": 4,
#     "text": "τοῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 17,
#     "end_char": 21
#   },
#   {
#     "id": 5,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 7,
#     "deprel": "case",
#     "start_char": 22,
#     "end_char": 24
#   },
#   {
#     "id": 6,
#     "text": "τῷ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 25,
#     "end_char": 27
#   },
#   {
#     "id": 7,
#     "text": "πεδίῳ",
#     "lemma": "πεδίον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Neut|Number=Sing",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 28,
#     "end_char": 33
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 6,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "πέμπεις",
#     "lemma": "πέμπω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "δῶρα",
#     "lemma": "δῶρον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Neut|Number=Plur",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 21,
#     "end_char": 25
#   },
#   {
#     "id": 6,
#     "text": "καλά",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Plur",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 26,
#     "end_char": 30
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "ἡ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 4,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 1
#   },
#   {
#     "id": 2,
#     "text": "τοῦ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Gen|Definite=Def|Gender=Masc|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 2,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "στρατηγοῦ",
#     "lemma": "στρατηγός",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nmod",
#     "start_char": 6,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "φυγὴ",
#     "lemma": "φυγή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 7,
#     "deprel": "nsubj",
#     "start_char": 16,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 7,
#     "deprel": "advmod",
#     "start_char": 21,
#     "end_char": 24
#   },
#   {
#     "id": 6,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 7,
#     "deprel": "cop",
#     "start_char": 25,
#     "end_char": 27
#   },
#   {
#     "id": 7,
#     "text": "καλή",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 28,
#     "end_char": 32
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "ἐκ",
#     "lemma": "ἐκ",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 3,
#     "deprel": "case",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "τῆς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Gen|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 3,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "κώμης",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 7,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "ἄγει",
#     "lemma": "ἄγω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 17
#   },
#   {
#     "id": 5,
#     "text": "τοὺς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 6,
#     "deprel": "det",
#     "start_char": 18,
#     "end_char": 22
#   },
#   {
#     "id": 6,
#     "text": "πολεμίους",
#     "lemma": "πολέμιος",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 23,
#     "end_char": 32
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "αἱ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "σκηναὶ",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 6,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "δῆλαι",
#     "lemma": "δῆλος",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 18
#   },
#   {
#     "id": 5,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 4,
#     "deprel": "cop",
#     "start_char": 19,
#     "end_char": 23
#   }
# ]]
# []
# [[
#   {
#     "id": 1,
#     "text": "τ--",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 5,
#     "deprel": "discourse",
#     "start_char": 4,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "κωμ--",
#     "lemma": "κωμή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 5,
#     "deprel": "nsubj",
#     "start_char": 7,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 5,
#     "deprel": "cop",
#     "start_char": 13,
#     "end_char": 15
#   },
#   {
#     "id": 5,
#     "text": "φυλακή",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 22
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 4,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 4,
#     "deprel": "cop",
#     "start_char": 4,
#     "end_char": 8
#   },
#   {
#     "id": 3,
#     "text": "σκην--",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 9,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "τ--",
#     "lemma": "τίς",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Masc|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 19
#   },
#   {
#     "id": 5,
#     "text": "φυλακ--",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "nmod",
#     "start_char": 20,
#     "end_char": 27
#   },
#   {
#     "id": 6,
#     "text": "(singular)",
#     "lemma": "(singular)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 4,
#     "deprel": "advmod",
#     "start_char": 28,
#     "end_char": 38
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "--",
#     "lemma": "--",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 9,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "(article)",
#     "lemma": "(article)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 9,
#     "deprel": "nsubj",
#     "start_char": 3,
#     "end_char": 12
#   },
#   {
#     "id": 3,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 13,
#     "end_char": 15
#   },
#   {
#     "id": 4,
#     "text": "τῷ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 16,
#     "end_char": 18
#   },
#   {
#     "id": 5,
#     "text": "περδίῳ",
#     "lemma": "περδίον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Neut|Number=Sing",
#     "head": 9,
#     "deprel": "obl",
#     "start_char": 19,
#     "end_char": 25
#   },
#   {
#     "id": 6,
#     "text": "--",
#     "lemma": "--",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 9,
#     "deprel": "advmod",
#     "start_char": 26,
#     "end_char": 28
#   },
#   {
#     "id": 7,
#     "text": "(negative",
#     "lemma": "(negative",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 8,
#     "deprel": "amod",
#     "start_char": 29,
#     "end_char": 38
#   },
#   {
#     "id": 8,
#     "text": "adverb)",
#     "lemma": "adverb)",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Gen|Degree=Pos|Gender=Masc|Number=Sing",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 39,
#     "end_char": 46
#   },
#   {
#     "id": 9,
#     "text": "ἐθέλουσι",
#     "lemma": "ἐθέλω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Number=Plur|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 47,
#     "end_char": 55
#   },
#   {
#     "id": 10,
#     "text": "τὰς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 11,
#     "deprel": "det",
#     "start_char": 56,
#     "end_char": 59
#   },
#   {
#     "id": 11,
#     "text": "σπνδὰς",
#     "lemma": "σπνδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Plur",
#     "head": 9,
#     "deprel": "obj",
#     "start_char": 60,
#     "end_char": 66
#   },
#   {
#     "id": 12,
#     "text": "λυ--",
#     "lemma": "λυ--",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Masc|Number=Sing",
#     "head": 11,
#     "deprel": "nmod",
#     "start_char": 67,
#     "end_char": 71
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σπονδῶν",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυγῇ",
#     "lemma": "φυγή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 4
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "μάχην",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "κώμαις",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνάς",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 6
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "φυλακῆς",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Gen|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σπονδαί",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 7
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]]
# []
# [[
#   {
#     "id": 1,
#     "text": "οὐ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "φεύγομεν",
#     "lemma": "φεύγω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 3,
#     "end_char": 11
#   },
#   {
#     "id": 3,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 12,
#     "end_char": 14
#   },
#   {
#     "id": 4,
#     "text": "ταῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Plur|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 15,
#     "end_char": 19
#   },
#   {
#     "id": 5,
#     "text": "μάχαις",
#     "lemma": "μάχη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 20,
#     "end_char": 26
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "γὰρ",
#     "lemma": "γάρ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 6
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "iobj",
#     "start_char": 7,
#     "end_char": 13
#   },
#   {
#     "id": 4,
#     "text": "ἦν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 14,
#     "end_char": 16
#   },
#   {
#     "id": 5,
#     "text": "σκηνή",
#     "lemma": "σκηνή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 17,
#     "end_char": 22
#   },
#   {
#     "id": 6,
#     "text": "καλή",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 23,
#     "end_char": 27
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οἱ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Nom|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 2,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δ",
#     "lemma": "δ",
#     "upos": "NUM",
#     "xpos": "Ma",
#     "head": 6,
#     "deprel": "nsubj",
#     "start_char": 3,
#     "end_char": 4
#   },
#   {
#     "id": 3,
#     "text": "'ἐν",
#     "lemma": "'ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 5,
#     "deprel": "case",
#     "start_char": 4,
#     "end_char": 7
#   },
#   {
#     "id": 4,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 5,
#     "deprel": "det",
#     "start_char": 8,
#     "end_char": 10
#   },
#   {
#     "id": 5,
#     "text": "κώμῃ",
#     "lemma": "κώμη",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 6,
#     "deprel": "obl",
#     "start_char": 11,
#     "end_char": 15
#   },
#   {
#     "id": 6,
#     "text": "φυλάττουσι",
#     "lemma": "φυλάσσω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 16,
#     "end_char": 26
#   },
#   {
#     "id": 7,
#     "text": "τοὺς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Acc|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 8,
#     "deprel": "det",
#     "start_char": 27,
#     "end_char": 31
#   },
#   {
#     "id": 8,
#     "text": "ἵππους",
#     "lemma": "ἵππος",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Masc|Number=Plur",
#     "head": 6,
#     "deprel": "obj",
#     "start_char": 32,
#     "end_char": 38
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "οὐκ",
#     "lemma": "οὐ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "feats": "Polarity=Neg",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3
#   },
#   {
#     "id": 2,
#     "text": "ἦσαν",
#     "lemma": "εἰμί",
#     "upos": "AUX",
#     "xpos": "V-",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 4,
#     "end_char": 8
#   },
#   {
#     "id": 3,
#     "text": "σπονδαὶ",
#     "lemma": "σπονδή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Nom|Gender=Fem|Number=Plur",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 9,
#     "end_char": 16
#   },
#   {
#     "id": 4,
#     "text": "τοῖς",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Masc|Number=Plur|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 17,
#     "end_char": 21
#   },
#   {
#     "id": 5,
#     "text": "ἐν",
#     "lemma": "ἐν",
#     "upos": "ADP",
#     "xpos": "R-",
#     "head": 7,
#     "deprel": "case",
#     "start_char": 22,
#     "end_char": 24
#   },
#   {
#     "id": 6,
#     "text": "τῷ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Dem",
#     "head": 7,
#     "deprel": "det",
#     "start_char": 25,
#     "end_char": 27
#   },
#   {
#     "id": 7,
#     "text": "πεδίῳ",
#     "lemma": "πεδίον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Neut|Number=Sing",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 28,
#     "end_char": 33
#   }
# ]]
# [[
#   {
#     "id": 1,
#     "text": "τῇ",
#     "lemma": "ὁ",
#     "upos": "DET",
#     "xpos": "S-",
#     "feats": "Case=Dat|Definite=Def|Gender=Fem|Number=Sing|PronType=Dem",
#     "head": 3,
#     "deprel": "det",
#     "start_char": 0,
#     "end_char": 2
#   },
#   {
#     "id": 2,
#     "text": "δὲ",
#     "lemma": "δέ",
#     "upos": "ADV",
#     "xpos": "Df",
#     "head": 4,
#     "deprel": "discourse",
#     "start_char": 3,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "φυλακῇ",
#     "lemma": "φυλακή",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Dat|Gender=Fem|Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 6,
#     "end_char": 12
#   },
#   {
#     "id": 4,
#     "text": "πέμπεις",
#     "lemma": "πέμπω",
#     "upos": "VERB",
#     "xpos": "V-",
#     "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 13,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "δῶρα",
#     "lemma": "δῶρον",
#     "upos": "NOUN",
#     "xpos": "Nb",
#     "feats": "Case=Acc|Gender=Neut|Number=Plur",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 21,
#     "end_char": 25
#   },
#   {
#     "id": 6,
#     "text": "καλά",
#     "lemma": "καλός",
#     "upos": "ADJ",
#     "xpos": "A-",
#     "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Plur",
#     "head": 5,
#     "deprel": "amod",
#     "start_char": 26,
#     "end_char": 30
#   }
# ]]
